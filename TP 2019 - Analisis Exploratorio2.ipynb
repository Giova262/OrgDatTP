# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
sns.set(style="darkgrid")

# %%
#Abro el csv
df_zonap = pd.read_csv('../Archivos CSV/trainTP12019.csv'
            ,dtype={
             "id":np.int32
            ,"titulo":'category'
            ,"fecha":str 
            ,"ciudad": 'category'
            ,"provincia": 'category'
            ,"tipodepropiedad": 'category' })

df_zonap.head(3)
# Out:
#        id                                 titulo  \
# 0  254099                      depto. tipo a-402
# 1   53461         condominio horizontal en venta
# 2  247984  casa en venta urbi 3 recamaras tonala
#
#                                          descripcion     tipodepropiedad  \
# 0  depto. interior de 80.15m2, consta de sala com...         Apartamento
# 1  <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 2  descripcion \nla mejor ubicacion residencial e...                Casa
#
#                          direccion                  ciudad         provincia  \
# 0  Avenida Division del Norte 2005           Benito Juárez  Distrito Federal
# 1                       AV. MEXICO  La Magdalena Contreras  Distrito Federal
# 2                      Urbi Tonala                  Tonalá           Jalisco
#
#    antiguedad  habitaciones  garages  ...   idzona        lat        lng  \
# 0         NaN           2.0      1.0  ...  23533.0        NaN        NaN
# ...

# %%
#Cambio la fecha a Datatime
df_zonap['fecha'] = pd.to_datetime(df_zonap['fecha'])

# %% [markdown]
# # Analisis Exploratario

# %%
#Distribucion de las posiciones de las propiedades -Color son los precios ¿Donde estan las casas mas caras?
df_zonap.plot(kind='scatter',c='precio',colormap='brg',title='Casas Precio',y='lat',x='lng',alpha=1,figsize=(10,10))

# %%
#Lugares donde se publican casas con piscina
sns.lmplot(x='lng',y='lat',hue="piscina",data=df_zonap,fit_reg=True)

# %%
#Lugares donde se publican casas con escuelas cercanas
sns.lmplot(x='lng',y='lat',hue="escuelascercanas",data=df_zonap,fit_reg=True)

# %%
#Lugares donde se publican casas con centros comerciales cercanaos
sns.lmplot(x='lng',y='lat',hue="centroscomercialescercanos",data=df_zonap,fit_reg=True)

# %%
#Lugares donde se publican casas tienen un SUM es un espacio para usos multiples(Mas que nada edificios)
sns.lmplot(x='lng',y='lat',hue="usosmultiples",data=df_zonap,fit_reg=True)

# %%
#Lugares donde se publican casas tienen gimnasio
sns.lmplot(x='lng',y='lat',hue="gimnasio",data=df_zonap,fit_reg=True)

# %%
#Lugares donde se publican casas tienen baños
sns.lmplot(x='lng',y='lat',hue="banos",data=df_zonap,fit_reg=True)

# %%
#Lugares donde se publican casas tienen baños
sns.lmplot(x='lng',y='lat',hue="garages",data=df_zonap,fit_reg=True)

# %%
#Lugares de las tipo de propiedades
fig, ax = pyplot.subplots(figsize=(15, 15))
sns.scatterplot(x='lng',y='lat',hue="tipodepropiedad",data=df_zonap , size='tipodepropiedad' ,sizes=(20, 200))

# %%
# Precio y tipo de propiedad
fig, ax = pyplot.subplots(figsize=(20, 20))
g = sns.violinplot(x='tipodepropiedad', y='precio', data=df_zonap ,size = 20 , rot=100, aspect=1.5)
g.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Apartamento'),
#  Text(0, 0, 'Bodega comercial'),
#  Text(0, 0, 'Casa'),
#  Text(0, 0, 'Casa en condominio'),
#  Text(0, 0, 'Casa uso de suelo'),
#  Text(0, 0, 'Departamento Compartido'),
#  Text(0, 0, 'Duplex'),
#  Text(0, 0, 'Edificio'),
#  Text(0, 0, 'Huerta'),
#  Text(0, 0, 'Inmuebles productivos urbanos'),
#  Text(0, 0, 'Local Comercial'),
#  Text(0, 0, 'Local en centro comercial'),
#  Text(0, 0, 'Lote'),
#  Text(0, 0, 'Nave industrial'),
#  Text(0, 0, 'Oficina comercial'),
#  Text(0, 0, 'Otros'),
#  Text(0, 0, 'Quinta Vacacional'),
#  Text(0, 0, 'Rancho'),
#  Text(0, 0, 'Terreno'),
#  Text(0, 0, 'Terreno comercial'),
#  Text(0, 0, 'Terreno industrial'),
#  Text(0, 0, 'Villa'),
#  Text(0, 0, 'Hospedaje'),
#  Text(0, 0, 'Garage')]
